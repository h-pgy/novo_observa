# %%
from source.load_data import DataLoader
from source.clean_data import CleanData
import pandas as pd
import geopandas as gpd

# %%
d = DataLoader()

# %%
d.collections
# Out:
# dict_keys(['educacao', 'esporte-e-lazer', 'financas-publicas', 'gestao-publica', 'meio-ambiente', 'mobilidade-e-seguranca-no-transito', 'moradia-e-saneamento-basico'])

# %%
dados = d.open_collection('educacao')

# %%
alunos = dados[list(dados.keys())[1]]

# %%
limpar = CleanData()

# %%
limpar(alunos)
# Out:
# {'codigo': 'alunos-da-rede-municipal-de-ensino-da-raca-cor-branca',
#  'desc': 'Alunos da rede municipal de ensino da raça/cor branca (%)  Expressa o percentual de alunos da raça/cor branca matriculados na rede municipal de ensino.',
#  'data': {'distritos': [{'periodo': 2020,
#     'valor': 62.91,
#     'regiao': 'água rasa'},
#    {'periodo': 2020, 'valor': 36.85, 'regiao': 'anhanguera'},
#    {'periodo': 2020, 'valor': 52.59, 'regiao': 'aricanduva'},
#    {'periodo': 2020, 'valor': 41.37, 'regiao': 'artur alvim'},
#    {'periodo': 2020, 'valor': 38.49, 'regiao': 'bela vista'},
#    {'periodo': 2020, 'valor': 38.99, 'regiao': 'belém'},
#    {'periodo': 2020, 'valor': 34.66, 'regiao': 'bom retiro'},
#    {'periodo': 2020, 'valor': 42.63, 'regiao': 'brás'},
#    {'periodo': 2020, 'valor': 38.77, 'regiao': 'brasilândia'},
#    {'periodo': 2020, 'valor': 46.46, 'regiao': 'butantã'},
#    {'periodo': 2020, 'valor': 45.58, 'regiao': 'cachoeirinha'},
# ...
